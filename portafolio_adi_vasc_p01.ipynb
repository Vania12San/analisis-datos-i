# %% [markdown]
# <a href="https://colab.research.google.com/github/Vania12San/analisis-datos-i/blob/main/portafolio_adi_vasc_p01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TEMA ELEGIDO
#
# MERCADOTECNIA ESTRATÉGICA- "QUIEN ES QUIEN EN LOS PRECIOS"

# %%
library(readr)

# %%
datos <- read_csv("11-2025_01.csv")
# Out:
# Rows: 486182 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (12): producto, presentacion, marca, categoria, catalogo, fecha_registro...
# dbl  (1): precio
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
datos
# Out:
#        producto
# 1      Aceite
# 2      Arroz
# 3      Atún
# 4      Atún
# 5      Azúcar
# 6      Azúcar
# 7      Carne Cerdo
# 8      Carne Cerdo
# 9      Carne Cerdo
# 10     Carne Pollo
# 11     Carne Pollo
# 12     Carne Pollo
# 13     Carne Pollo
# 14     Carne Pollo
# 15     Carne Res
# 16     Carne Res
# 17     Carne Res
# 18     Carne Res
# 19     Cebolla
# 20     Cebolla
# 21     Chile Fresco
# 22     Frijol
# 23     Huevo
# 24     Jabón de Tocador
# 25     Jabón de Tocador
# 26     Jitomate
# 27     Jitomate
# 28     Leche Ultrapasteurizada
# 29     Leche Ultrapasteurizada
# 30     Limón
# ⋮      ⋮
# 486153 Electrónicos de Video
# 486154 Electrónicos de Video
# 486155 Electrónicos de Video
# 486156 Electrónicos de Video
# 486157 Electrónicos de Video
# 486158 Electrónicos de Video
# 486159 Extractores de Jugos y Exprimidores
# 486160 Extractores de Jugos y Exprimidores
# 486161 Extractores de Jugos y Exprimidores
# 486162 Freidoras de Aire
# 486163 Horno de Microondas
# ...

# %%
head(datos)
# Out:
#   producto presentacion                                           marca
# 1 Aceite   Botella 850 Ml. Vegetal                                Precíssimo
# 2 Arroz    Bolsa 900 Gr. Extra. Grano Largo                       Precíssimo
# 3 Atún     Lata 140 Gr. Desmenuzado en Aceite. Standard, Sin Soya Fresh Label
# 4 Atún     Lata 140 Gr. Desmenuzado en Agua. Standard, Sin Soya   Fresh Label
# 5 Azúcar   Bolsa Plástico 900 Gr. Estándar                        Precíssimo
# 6 Azúcar   Bolsa Plástico 900 Gr. Estándar                        Zulka
#   categoria                         catalogo precio fecha_registro
# 1 Aceites y Grasas Veg. Comestibles Pacic    26.5   03/11/2025
# 2 Arroz y Cereales Preparados       Pacic    16.9   03/11/2025
# 3 Pescados y Mariscos en Conserva   Pacic    17.9   03/11/2025
# 4 Pescados y Mariscos en Conserva   Pacic    17.9   03/11/2025
# 5 Azucar                            Pacic    25.9   03/11/2025
# ...

# %%
glimpse(datos)
# Out:
# Rows: 486,182
# Columns: 13
# $ producto         <chr> "Aceite", "Arroz", "Atún", "Atún", "Azúcar", "Azúcar"…
# $ presentacion     <chr> "Botella 850 Ml. Vegetal", "Bolsa 900 Gr. Extra. Gran…
# $ marca            <chr> "Precíssimo", "Precíssimo", "Fresh Label", "Fresh Lab…
# $ categoria        <chr> "Aceites y Grasas Veg. Comestibles", "Arroz y Cereale…
# $ catalogo         <chr> "Pacic", "Pacic", "Pacic", "Pacic", "Pacic", "Pacic",…
# $ precio           <dbl> 26.50, 16.90, 17.90, 17.90, 25.90, 24.90, 128.00, 88.…
# $ fecha_registro   <chr> "03/11/2025", "03/11/2025", "03/11/2025", "03/11/2025…
# $ cadena_comercial <chr> "Mega Soriana", "Mega Soriana", "Mega Soriana", "Mega…
# $ giro             <chr> "Supermercado / Tienda de Autoservicio", "Supermercad…
# $ nombre_comercial <chr> "Mega Soriana Sucursal Aguascalientes", "Mega Soriana…
# $ direccion        <chr> "Aguascalientes Nte. 802. Esq. Blvd. a Zacatecas. Col…
# ...

# %% [markdown]
# ## RAZÓN DE ELECCIÓN
#
# Para mi proyecto de Mercadotecnia Estratégica en Google Colab, voy a analizar la base de datos de Profeco para entender cómo interactúan el pricing, la competencia y la segmentación geográfica en el mercado real. Trabajar con estos 486182 registros me permitirá evaluar la enorme dispersión de precios —como la brecha del 212% en el arroz— entre 63 cadenas comerciales y 30 estados, identificando las estrategias de fijación de precios de cada retail (desde Everyday Low Price hasta High-Low Pricing) y determinando cómo varía la sensibilidad al precio según el giro comercial y la ubicación regional.
